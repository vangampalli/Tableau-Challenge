# %%
import pandas as pd
import datetime

# %%
df022020 = 'JC-202002-citibike-tripdata.csv'
df032020 = 'JC-202003-citibike-tripdata.csv'
df042020 = 'JC-202004-citibike-tripdata.csv'
df062020 = 'JC-202006-citibike-tripdata.csv'
df072020 = 'JC-202007-citibike-tripdata.csv'
df082020 = 'JC-202008-citibike-tripdata.csv'
df102020 = 'JC-202010-citibike-tripdata.csv'
df112020 = 'JC-202011-citibike-tripdata.csv'
df122020 = 'JC-202012-citibike-tripdata.csv'
df012021 = 'JC-202101-citibike-tripdata.csv'
df022021 = 'JC-202102-citibike-tripdata.csv'
df0220 = pd.read_csv(df022020)
df0320 = pd.read_csv(df032020)
df0420 = pd.read_csv(df042020)
df0620 = pd.read_csv(df062020)
df0720 = pd.read_csv(df072020)
df0820 = pd.read_csv(df082020)
df1020 = pd.read_csv(df102020)
df1120 = pd.read_csv(df112020)
df1220 = pd.read_csv(df122020)
df0121 = pd.read_csv(df012021)
df0221 = pd.read_csv(df022021)

# %%
feb20 = df0220.columns
print(feb20)
feb21 = df0221.columns
print(feb21)
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
df0221
# Out:
#                ride_id rideable_type           started_at  \
# 0     121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1     FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2     39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3     A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4     75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                ...           ...                  ...
# 4876  3F8FD9A051C0E3DA   docked_bike  2021-02-24 18:05:45
# 4877  B91F3593C0C06D04   docked_bike  2021-02-22 18:22:04
# 4878  A790954A017D07CB   docked_bike  2021-02-13 12:21:49
# 4879  42B1932D06CEE034   docked_bike  2021-02-25 11:20:29
# 4880  F71732ECE7CD02CF   docked_bike  2021-02-19 13:59:22
#
#                  ended_at          start_station_name start_station_id  \
# 0     2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1     2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
df0221['ended_at'] = pd.to_datetime(df0221['ended_at'])
df0221['ended_at'].dtype
df0221['started_at'] = pd.to_datetime(df0221['started_at'])
df0221['started_at'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df0221['tripduration'] = df0221['ended_at'] - df0221['started_at']

# %%
df0221['tripduration'] = df0221['tripduration'].dt.total_seconds()
df0221
# Out:
#                ride_id rideable_type          started_at            ended_at  \
# 0     121DD7DD23CB1335   docked_bike 2021-02-03 23:11:28 2021-02-03 23:18:28
# 1     FD73FB85F008349D   docked_bike 2021-02-27 16:34:05 2021-02-27 16:56:40
# 2     39F9E6663CB5FDF6   docked_bike 2021-02-26 23:16:04 2021-02-26 23:22:25
# 3     A64745CB0792EC6F   docked_bike 2021-02-24 16:51:50 2021-02-24 17:16:09
# 4     75CC76EB9543764A   docked_bike 2021-02-24 20:44:16 2021-02-24 20:44:46
# ...                ...           ...                 ...                 ...
# 4876  3F8FD9A051C0E3DA   docked_bike 2021-02-24 18:05:45 2021-02-24 18:12:27
# 4877  B91F3593C0C06D04   docked_bike 2021-02-22 18:22:04 2021-02-22 18:28:45
# 4878  A790954A017D07CB   docked_bike 2021-02-13 12:21:49 2021-02-13 12:27:51
# 4879  42B1932D06CEE034   docked_bike 2021-02-25 11:20:29 2021-02-25 11:25:23
# 4880  F71732ECE7CD02CF   docked_bike 2021-02-19 13:59:22 2021-02-19 14:05:47
#
# ...

# %%
df0221 = df0221.rename(columns={'ride_id':'bikeid', 'started_at':'starttime', 'ended_at':'stoptime', 'start_station_name':'start station name', 'start_station_id':'start station id', 'end_station_name': 'end station name', 'end_station_id':'end station id', 'start_lat':'start station latitude', 'start_lng':'start station longitude', 'end_lat':'end station latitude', 'end_lng':'end station longitude', 'member_casual':'usertype'
})

# %%
df0221
# Out:
#                 bikeid rideable_type           starttime            stoptime  \
# 0     121DD7DD23CB1335   docked_bike 2021-02-03 23:11:28 2021-02-03 23:18:28
# 1     FD73FB85F008349D   docked_bike 2021-02-27 16:34:05 2021-02-27 16:56:40
# 2     39F9E6663CB5FDF6   docked_bike 2021-02-26 23:16:04 2021-02-26 23:22:25
# 3     A64745CB0792EC6F   docked_bike 2021-02-24 16:51:50 2021-02-24 17:16:09
# 4     75CC76EB9543764A   docked_bike 2021-02-24 20:44:16 2021-02-24 20:44:46
# ...                ...           ...                 ...                 ...
# 4876  3F8FD9A051C0E3DA   docked_bike 2021-02-24 18:05:45 2021-02-24 18:12:27
# 4877  B91F3593C0C06D04   docked_bike 2021-02-22 18:22:04 2021-02-22 18:28:45
# 4878  A790954A017D07CB   docked_bike 2021-02-13 12:21:49 2021-02-13 12:27:51
# 4879  42B1932D06CEE034   docked_bike 2021-02-25 11:20:29 2021-02-25 11:25:23
# 4880  F71732ECE7CD02CF   docked_bike 2021-02-19 13:59:22 2021-02-19 14:05:47
#
# ...

# %%
df0221['stoptime'] = df0221['stoptime'].astype(object)
df0221['starttime'] = df0221['starttime'].astype(object)
df0221['tripduration'] = df0221['tripduration'].astype(object)

# %%
df0221
# Out:
#                 bikeid rideable_type            starttime  \
# 0     121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1     FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2     39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3     A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4     75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                ...           ...                  ...
# 4876  3F8FD9A051C0E3DA   docked_bike  2021-02-24 18:05:45
# 4877  B91F3593C0C06D04   docked_bike  2021-02-22 18:22:04
# 4878  A790954A017D07CB   docked_bike  2021-02-13 12:21:49
# 4879  42B1932D06CEE034   docked_bike  2021-02-25 11:20:29
# 4880  F71732ECE7CD02CF   docked_bike  2021-02-19 13:59:22
#
#                  stoptime          start station name start station id  \
# 0     2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1     2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
unmatched = []
unmatched2 = []
for col in df0221.columns:
    if col not in df0220.columns:
        unmatched.append(col)
for col in df0220.columns:
    if col not in df0221.columns:
        unmatched2.append(col)
print(unmatched)
print(unmatched2)
# Out:
# ['rideable_type']
# ['birth year', 'gender']

# %%
months11 = pd.concat([df0220, df0320, df0420, df0620, df0720, df0820, df1020, df1120, df1220, df0121])
months11 = months11.drop(columns = ['birth year', 'gender'])
df0221 = df0221.drop(columns = ['rideable_type'])
months11
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1               206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2               859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3               693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4              1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id  start station name  start station latitude  \
# ...

# %%
df0221reorder = df0221.reindex(columns = ['tripduration', 'starttime', 'stoptime', 'start station id', 'start station name', 'start station latitude', 'start station longitude', 'start station latitude', 'start station longitude', 'start station id', 'end station name', 'end station latitude', 'end station longitude', 'bikeid', 'usertype'])
df0221reorder
# Out:
#      tripduration            starttime             stoptime start station id  \
# 0           420.0  2021-02-03 23:11:28  2021-02-03 23:18:28            JC105
# 1          1355.0  2021-02-27 16:34:05  2021-02-27 16:56:40            JC008
# 2           381.0  2021-02-26 23:16:04  2021-02-26 23:22:25            JC103
# 3          1459.0  2021-02-24 16:51:50  2021-02-24 17:16:09            JC105
# 4            30.0  2021-02-24 20:44:16  2021-02-24 20:44:46            JC105
# ...           ...                  ...                  ...              ...
# 4876        402.0  2021-02-24 18:05:45  2021-02-24 18:12:27            JC014
# 4877        401.0  2021-02-22 18:22:04  2021-02-22 18:28:45            JC014
# 4878        362.0  2021-02-13 12:21:49  2021-02-13 12:27:51            JC014
# 4879        294.0  2021-02-25 11:20:29  2021-02-25 11:25:23            JC014
# 4880        385.0  2021-02-19 13:59:22  2021-02-19 14:05:47            JC014
#
# ...

# %%
months11.to_csv('months11.csv')
df0221reorder.to_csv('0221.csv')
